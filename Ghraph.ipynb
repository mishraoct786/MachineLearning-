# %% [markdown]
# <a href="https://colab.research.google.com/github/mishraoct786/MachineLearning-/blob/main/Ghraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
x=[12,14,20]
y=[22,43,16]
z=[11,3,4]
plt.plot(x,y,'r',label='line')
plt.legend()
plt.title('Graph')
plt.grid()
plt.show()

# %%
from matplotlib import pyplot as plt
plt.bar([1,2,3,4],[1,2,3,4])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #Bar

# %%
age=[12,45,67,88,43,66,32,65,48,81]
bins =[0,5,10,15,20]
plt.hist(age,bins,histtype='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
x=[1,8,7,6,4,8,3,7]
y=[36,38,91,22,10,6,40,34]
plt.scatter(x,y,color='r',label='line 1')

# %%
x=[1,8,7,6,4,8,3,7]
y=[36,38,91,22,10,6,40,34]
plt.plot(x,y,color='r',label='line1')

# %%
import numpy as np
plt.plot([1,2,3,4],[8,6,5,4],'ro-')
plt.plot([1,2,3,4],[3,9,6,4],label='line2')
plt.plot([1,6,2,7],[8,6,7,4],'g*')
plt.legend()
plt.show()
